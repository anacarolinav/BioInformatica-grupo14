# %%
import pandas as pd

# %% [markdown]
# # ETAPA 3

# %%
# %run \Users\jfpal\Downloads\Trabalho\etapa2.ipynb
# Out:
# <bound method NDFrame.head of                  Diagnosis Age  Fraction Genome Altered  Longest Dimension  \
# Sample ID
# TCGA-05-4244-01           70.0                   0.4565                1.1
# TCGA-05-4249-01           67.0                   0.2221                1.4
# TCGA-05-4250-01           79.0                   0.2362                1.2
# TCGA-05-4382-01           68.0                   0.0854                0.9
# TCGA-05-4384-01           66.0                   0.0661                0.8
# ...                        ...                      ...                ...
# TCGA-NJ-A55O-01           56.0                   0.0194                NaN
# TCGA-NJ-A55R-01           67.0                   0.0760                NaN
# TCGA-NJ-A7XG-01           49.0                   0.4205                NaN
# TCGA-O1-A52J-01           74.0                   0.5443                NaN
# TCGA-S2-AA1A-01           68.0                   0.0598                NaN
#
# ...

# %%
print(input_sc.shape)
# Out:
# (517, 306)

# %%
#valores random
out = new_meta["Patient's Vital Status"].values
#particao dos dados
particao = int(input_sc.shape[0]/3)

print("elementos totais=", input_sc.shape[0])
print("elementos de teste=", particao)
indice = np.random.permutation(input_sc.shape[0])

train_in = input_sc[indice[:-particao]]
train_out = out[indice[:-particao]]
test_in = input_sc[indice[-particao:]]
test_out = out[indice[-particao:]]
# Out:
# elementos totais= 517
# elementos de teste= 172

# %%
from sklearn import tree

tree_model = tree.DecisionTreeClassifier()
tree_model = tree_model.fit(train_in, train_out)

from sklearn.metrics import accuracy_score

preds = tree_model.predict(test_in)

print("% de valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%")
# Out:
# % de valores corretamente previstos:  57.55813953488372 %

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_model, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.52307692 0.47692308 0.53846154 0.56923077 0.50769231 0.609375
#  0.5        0.515625  ]
# 0.5300480769230769

# %%
from sklearn import svm

svm_model = svm.SVC(kernel='linear', C=1)
svm_model.fit(train_in, train_out)

from sklearn.metrics import accuracy_score

preds = svm_model.predict(test_in)

print("% valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%")
# Out:
# % valores corretamente previstos:  63.372093023255815 %

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(svm_model, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.55384615 0.50769231 0.50769231 0.64615385 0.58461538 0.59375
#  0.546875   0.59375   ]
# 0.5667968750000001

# %%
from sklearn.naive_bayes import GaussianNB

gnb_model = GaussianNB()
gnb_model = gnb_model.fit(train_in, train_out)

from sklearn.metrics import accuracy_score

preds = gnb_model.predict(test_in)

print("% valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%")
# Out:
# % valores corretamente previstos:  68.02325581395348 %

# %%
scores = cross_val_score(gnb_model, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.63076923 0.53846154 0.58461538 0.6        0.63076923 0.671875
#  0.59375    0.5625    ]
# 0.6015925480769231

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(train_in,train_out)

preds = clf.predict(test_in)
print("% valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%")
# Out:
# % valores corretamente previstos:  65.11627906976744 %

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(clf, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.66153846 0.6        0.66153846 0.6        0.55384615 0.625
#  0.609375   0.65625   ]
# 0.6209435096153846

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(train_in, train_out)

preds = knn.predict(test_in)

print("% valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%" )
# Out:
# % valores corretamente previstos:  59.30232558139535 %
# C:\Users\jfpal\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(knn, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.56923077 0.63076923 0.58461538 0.50769231 0.61538462 0.546875
#  0.53125    0.5625    ]
# 0.5685396634615385
# C:\Users\jfpal\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(n_estimators=100, random_state=0)
ada.fit(train_in, train_out)

preds = ada.predict(test_in)
print("% valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%" )
# Out:
# % valores corretamente previstos:  62.2093023255814 %

# %%
scores = cross_val_score(ada, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.58461538 0.49230769 0.55384615 0.47692308 0.56923077 0.546875
#  0.515625   0.578125  ]
# 0.5396935096153846

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GBc = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,max_depth=1, random_state=0)
GBc.fit(train_in, train_out)

preds = GBc.predict(test_in)
print("% valores corretamente previstos: ", accuracy_score(test_out, preds)*100, "%" )
# Out:
# % valores corretamente previstos:  60.46511627906976 %

# %%
scores = cross_val_score(GBc, input_sc, out, cv = 8)
print(scores)
print(scores.mean())
# Out:
# [0.6        0.53846154 0.55384615 0.49230769 0.58461538 0.578125
#  0.546875   0.609375  ]
# 0.5629507211538463

# %% [markdown]
# Através do dataset escolhido, foram estudados diferentes modelos de previsão. De acordo com os resultados obtidos verifica-se que o método gaussiano que prevê corretamente uma maior percentagem de valores é o Naive Bayes, tendo-se obtido um valor de 68,02% de valores corretamente previstos. Através deste mesmo método, observa-se também o melhor valor de exatidão. No entanto, é de referir que nenhum dos modelos de previsão estudados permite obter um valor de exatidão suficiente, visto que todos apresentam valores inferiores a 90%, valor base a partir do qual se pode considerar uma boa previsão. Assim, pode-se concluir que nenhum dos modelos permite apoiar a decisão sobre o atributo em estudo. Assim, este estudo permite inferir que os atributos estudados não permitem concluir relativamente ao estado vital do paciente, ou seja, se este vive ou morre. Para futuros trabalhos, seria interessante recorrer a mais dados e dados diferentes sobre atributos mais especificos do adenocarcinoma em estudo.

# %% [markdown]
# # Conclusões finais

# %% [markdown]
# Como realçado anteriormente, os valores de previsão obtidos a partir dos distintos modelos não são satisfatórios, dado não serem superiores a 80%. Contudo, e de modo a garantir uma melhor previsibilidade dos resultados, foram realizadas avaliações a outras variáveis dos metadados, segundo os mesmos modelos, e não foi possível obter resultados mais favoráveis, pelo que se manteve a label inicialmente estabelecida.
# Concluindo, o presente dataset não permite tecer resultados indubitáveis sobre a vitalidade
# dos pacientes com cancro do pulmão, indiciando que a combinação destes atributos não
# testifica resultados vigorantes.
